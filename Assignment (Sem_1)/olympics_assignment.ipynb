# %%
import pandas as pd

# %%
data1=pd.read_csv("Olympics.csv")

# %%
# Retrieve all records from the Olympics table.

# %%
data1
# Out:
#     id                                name sex  age  height  weight  \
# 0    1                           A Dijiang   M   24   180.0    80.0
# 1    2                            A Lamusi   M   23   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M   24     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M   34     NaN     NaN
# 4    5            Christine Jacoba Aaftink   F   21   185.0    82.0
# ..  ..                                 ...  ..  ...     ...     ...
# 95  32                Olav Augunson Aarnes   M   23     NaN     NaN
# 96  33                 Mika Lauri Aarnikka   M   24   187.0    76.0
# 97  33                 Mika Lauri Aarnikka   M   28   187.0    76.0
# 98  34  Jamale (Djamel-) Aarrass (Ahrass-)   M   30   187.0    76.0
# 99  35              Dagfinn Sverre Aarskog   M   24   190.0    98.0
#
#               team  noc        games  year  season       city          sport  \
# ...

# %%
# Retrieve only the Athlete names and the Medals they won

# %%
data1['medal'].fillna(0, inplace=True)

# %%
data2= data1[data1['medal'] != 0]

# %%
data3=data2.groupby('name')['medal'].value_counts()

# %%
data3
# Out:
# name                       medal
# Alf Lied Aanning           Silver    1
# Arvo Ossian Aaltonen       Bronze    2
# Edgar Lindenau Aabye       Gold      1
# Juhamatti Tapio Aaltonen   Bronze    1
# Kjetil Andr Aamodt         Gold      4
#                            Bronze    2
#                            Silver    2
# Paavo Johannes Aaltonen    Gold      3
#                            Bronze    2
# Pepijn Aardewijn           Silver    1
# Ragnhild Margrethe Aamodt  Gold      1
# Willemien Aardenburg       Bronze    1
# Name: count, dtype: int64

# %%
# Count the total number of athletes in the dataset

# %%
data1['name'].nunique()
# Out:
# 35

# %%
#  Find all records of athletes who won a Gold medal

# %%
data4=data1[data1['medal']=='Gold']

# %%
data4
# Out:
#     id                       name sex  age  height  weight            team  \
# 3    4       Edgar Lindenau Aabye   M   34     NaN     NaN  Denmark/Sweden
# 42  17    Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland
# 44  17    Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland
# 48  17    Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland
# 60  20         Kjetil Andr Aamodt   M   20   176.0    85.0          Norway
# 73  20         Kjetil Andr Aamodt   M   30   176.0    85.0          Norway
# 76  20         Kjetil Andr Aamodt   M   30   176.0    85.0          Norway
# 78  20         Kjetil Andr Aamodt   M   34   176.0    85.0          Norway
# 79  21  Ragnhild Margrethe Aamodt   F   27   163.0     NaN          Norway
#
#     noc        games  year  season            city          sport  \
# 3   DEN  1900 Summer  1900  Summer           Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer          London     Gymnastics
# ...

# %%
# List all athletes who won Silver, ordered by the Year they won it.

# %%
data5=data1[data1['medal']=='Silver']

# %%
data6=data5.sort_values(by='year')

# %%
data6
# Out:
#     id                name sex  age  height  weight         team  noc  \
# 86  25    Alf Lied Aanning   M   24     NaN     NaN       Norway  NOR
# 63  20  Kjetil Andr Aamodt   M   22   176.0    85.0       Norway  NOR
# 67  20  Kjetil Andr Aamodt   M   22   176.0    85.0       Norway  NOR
# 92  30    Pepijn Aardewijn   M   26   189.0    72.0  Netherlands  NED
#
#           games  year  season         city          sport  \
# 86  1920 Summer  1920  Summer    Antwerpen     Gymnastics
# 63  1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 67  1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 92  1996 Summer  1996  Summer      Atlanta         Rowing
#
#                                               event   medal
# 86  "Gymnastics Men's Team All-Around, Free System"  Silver
# 63                     Alpine Skiing Men's Downhill  Silver
# 67                     Alpine Skiing Men's Combined  Silver
# 92           Rowing Men's Lightweight Double Sculls  Silver

# %%
# Count how many Gold, Silver, and Bronze medals each country has won.

# %%
data7=data1[data1['medal']!=0]

# %%
data8=data7.groupby('team')['medal'].value_counts()

# %%
data8
# Out:
# team            medal
# Denmark/Sweden  Gold      1
# Finland         Bronze    5
#                 Gold      3
# Netherlands     Bronze    1
#                 Silver    1
# Norway          Gold      5
#                 Silver    3
#                 Bronze    2
# Name: count, dtype: int64

# %%
# Find the athlete who has won the most medals

# %%
data8=data2.groupby('name')['medal'].count()

# %%
data8
# Out:
# name
# Alf Lied Aanning             1
# Arvo Ossian Aaltonen         2
# Edgar Lindenau Aabye         1
# Juhamatti Tapio Aaltonen     1
# Kjetil Andr Aamodt           8
# Paavo Johannes Aaltonen      5
# Pepijn Aardewijn             1
# Ragnhild Margrethe Aamodt    1
# Willemien Aardenburg         1
# Name: medal, dtype: int64

# %%
data9=data8.idxmax()

# %%
data9
# Out:
# 'Kjetil Andr Aamodt'

# %%
#  List athletes who won more than one medal in a single Olympic year.

# %%
data10 = data1.groupby(['year', 'name']).size()

# %%
data11=data10[data10>1]

# %%
data11
# Out:
# year  name
# 1912  Arvo Ossian Aaltonen                    2
# 1920  Arvo Ossian Aaltonen                    2
# 1932  Cornelia \Cor\" Aalten (-Strannood)"    2
# 1948  Paavo Johannes Aaltonen                 8
# 1952  Paavo Johannes Aaltonen                 8
# 1960  Nils Egil Aaness                        2
# 1988  Christine Jacoba Aaftink                2
# 1992  Christine Jacoba Aaftink                2
#       John Aalberg                            4
#       Kjetil Andr Aamodt                      4
#       Per Knut Aaland                         4
# 1994  Christine Jacoba Aaftink                2
#       John Aalberg                            4
#       Kjetil Andr Aamodt                      5
#       Per Knut Aaland                         4
# 1998  Kjetil Andr Aamodt                      4
# 2002  Kjetil Andr Aamodt                      5
# 2006  Kjetil Andr Aamodt                      2
# dtype: int64

# %%
# Calculate the average number of medals won per athlete for each country

# %%
data12 = data2.groupby(['team', 'name']).size().reset_index(name='Medal_Count')

# %%
data12
# Out:
#              team                       name  Medal_Count
# 0  Denmark/Sweden       Edgar Lindenau Aabye            1
# 1         Finland       Arvo Ossian Aaltonen            2
# 2         Finland   Juhamatti Tapio Aaltonen            1
# 3         Finland    Paavo Johannes Aaltonen            5
# 4     Netherlands           Pepijn Aardewijn            1
# 5     Netherlands       Willemien Aardenburg            1
# 6          Norway           Alf Lied Aanning            1
# 7          Norway         Kjetil Andr Aamodt            8
# 8          Norway  Ragnhild Margrethe Aamodt            1

# %%
data13 = data12.groupby('team')['Medal_Count'].mean().reset_index(name='Average')

# %%
data13
# Out:
#              team   Average
# 0  Denmark/Sweden  1.000000
# 1         Finland  2.666667
# 2     Netherlands  1.000000
# 3          Norway  3.333333

# %%
# Find the country that showed the largest improvement in total medals won from one 
# Olympics to the next.

# %%
data14= data2.groupby(['year', 'team']).size().reset_index(name='Medal_Count')

# %%
data14
# Out:
#     year            team  Medal_Count
# 0   1900  Denmark/Sweden            1
# 1   1920         Finland            2
# 2   1920          Norway            1
# 3   1948         Finland            4
# 4   1952         Finland            1
# 5   1988     Netherlands            1
# 6   1992          Norway            2
# 7   1994          Norway            3
# 8   1996     Netherlands            1
# 9   2002          Norway            2
# 10  2006          Norway            1
# 11  2008          Norway            1
# 12  2014         Finland            1

# %%
data14 = data14.sort_values(by=['team', 'year'])

# %%
data14
# Out:
#     year            team  Medal_Count
# 0   1900  Denmark/Sweden            1
# 1   1920         Finland            2
# 3   1948         Finland            4
# 4   1952         Finland            1
# 12  2014         Finland            1
# 5   1988     Netherlands            1
# 8   1996     Netherlands            1
# 2   1920          Norway            1
# 6   1992          Norway            2
# 7   1994          Norway            3
# 9   2002          Norway            2
# 10  2006          Norway            1
# 11  2008          Norway            1

# %%
data14['Medal_Difference'] = data14.groupby('team')['Medal_Count'].diff()

# %%
data14
# Out:
#     year            team  Medal_Count  Medal_Difference
# 0   1900  Denmark/Sweden            1               NaN
# 1   1920         Finland            2               NaN
# 3   1948         Finland            4               2.0
# 4   1952         Finland            1              -3.0
# 12  2014         Finland            1               0.0
# 5   1988     Netherlands            1               NaN
# 8   1996     Netherlands            1               0.0
# 2   1920          Norway            1               NaN
# 6   1992          Norway            2               1.0
# 7   1994          Norway            3               1.0
# 9   2002          Norway            2              -1.0
# 10  2006          Norway            1              -1.0
# 11  2008          Norway            1               0.0

# %%
data15= data14.loc[data15['Medal_Difference'].idxmax()]

# %%
data15
# Out:
# year                   1948
# team                Finland
# Medal_Count               4
# Medal_Difference        2.0
# Name: 3, dtype: object

# %%
# Show the year difference between the first and last medal won by each country.

# %%
data16 = data2.groupby('team')['year'].agg(['min', 'max'])

# %%
data16
# Out:
#                  min   max
# team
# Denmark/Sweden  1900  1900
# Finland         1920  2014
# Netherlands     1988  1996
# Norway          1920  2008

# %%
data16['Year_Difference'] = (data16['max'] - data16['min'])

# %%
data16
# Out:
#                  min   max  Year_Difference
# team
# Denmark/Sweden  1900  1900                0
# Finland         1920  2014               94
# Netherlands     1988  1996                8
# Norway          1920  2008               88

# %%
# Find athletes who won medals in three consecutive Olympic games in the same event.

# %%
data17 = data2.sort_values(by=['name', 'event', 'year'])

# %%
data17
# Out:
#     id                       name sex  age  height  weight            team  \
# 86  25           Alf Lied Aanning   M   24     NaN     NaN          Norway
# 37  15       Arvo Ossian Aaltonen   M   30     NaN     NaN         Finland
# 38  15       Arvo Ossian Aaltonen   M   30     NaN     NaN         Finland
# 3    4       Edgar Lindenau Aabye   M   34     NaN     NaN  Denmark/Sweden
# 40  16   Juhamatti Tapio Aaltonen   M   28   184.0    85.0         Finland
# 67  20         Kjetil Andr Aamodt   M   22   176.0    85.0          Norway
# 76  20         Kjetil Andr Aamodt   M   30   176.0    85.0          Norway
# 63  20         Kjetil Andr Aamodt   M   22   176.0    85.0          Norway
# 61  20         Kjetil Andr Aamodt   M   20   176.0    85.0          Norway
# 60  20         Kjetil Andr Aamodt   M   20   176.0    85.0          Norway
# 64  20         Kjetil Andr Aamodt   M   22   176.0    85.0          Norway
# ...

# %%
data17['Consecutive_Count'] = data17.groupby(['name', 'event'])['year'].diff()

# %%
data17
# Out:
#     id                       name sex  age  height  weight            team  \
# 86  25           Alf Lied Aanning   M   24     NaN     NaN          Norway
# 37  15       Arvo Ossian Aaltonen   M   30     NaN     NaN         Finland
# 38  15       Arvo Ossian Aaltonen   M   30     NaN     NaN         Finland
# 3    4       Edgar Lindenau Aabye   M   34     NaN     NaN  Denmark/Sweden
# 40  16   Juhamatti Tapio Aaltonen   M   28   184.0    85.0         Finland
# 67  20         Kjetil Andr Aamodt   M   22   176.0    85.0          Norway
# 76  20         Kjetil Andr Aamodt   M   30   176.0    85.0          Norway
# 63  20         Kjetil Andr Aamodt   M   22   176.0    85.0          Norway
# 61  20         Kjetil Andr Aamodt   M   20   176.0    85.0          Norway
# 60  20         Kjetil Andr Aamodt   M   20   176.0    85.0          Norway
# 64  20         Kjetil Andr Aamodt   M   22   176.0    85.0          Norway
# ...

# %%
data18 = data17[data17['Consecutive_Count']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 data18 = data17[data17['Consecutive_Count']]
#
# File ~\anaconda4\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda4\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# ...

# %%
data17['Consecutive_Count'].fillna(value=0,inplace=True)

# %%
data17
# Out:
#     id                       name sex  age  height  weight            team  \
# 86  25           Alf Lied Aanning   M   24     NaN     NaN          Norway
# 37  15       Arvo Ossian Aaltonen   M   30     NaN     NaN         Finland
# 38  15       Arvo Ossian Aaltonen   M   30     NaN     NaN         Finland
# 3    4       Edgar Lindenau Aabye   M   34     NaN     NaN  Denmark/Sweden
# 40  16   Juhamatti Tapio Aaltonen   M   28   184.0    85.0         Finland
# 67  20         Kjetil Andr Aamodt   M   22   176.0    85.0          Norway
# 76  20         Kjetil Andr Aamodt   M   30   176.0    85.0          Norway
# 63  20         Kjetil Andr Aamodt   M   22   176.0    85.0          Norway
# 61  20         Kjetil Andr Aamodt   M   20   176.0    85.0          Norway
# 60  20         Kjetil Andr Aamodt   M   20   176.0    85.0          Norway
# 64  20         Kjetil Andr Aamodt   M   22   176.0    85.0          Norway
# ...

# %%
data18=data17[data17['Consecutive_Count']!=0]

# %%
data18
# Out:
#     id                     name sex  age  height  weight     team  noc  \
# 76  20       Kjetil Andr Aamodt   M   30   176.0    85.0   Norway  NOR
# 64  20       Kjetil Andr Aamodt   M   22   176.0    85.0   Norway  NOR
# 73  20       Kjetil Andr Aamodt   M   30   176.0    85.0   Norway  NOR
# 78  20       Kjetil Andr Aamodt   M   34   176.0    85.0   Norway  NOR
# 50  17  Paavo Johannes Aaltonen   M   32   175.0    64.0  Finland  FIN
#
#           games  year  season            city          sport  \
# 76  2002 Winter  2002  Winter  Salt Lake City  Alpine Skiing
# 64  1994 Winter  1994  Winter     Lillehammer  Alpine Skiing
# 73  2002 Winter  2002  Winter  Salt Lake City  Alpine Skiing
# 78  2006 Winter  2006  Winter          Torino  Alpine Skiing
# 50  1952 Summer  1952  Summer        Helsinki     Gymnastics
#
#                                event   medal  Consecutive_Count
# 76      Alpine Skiing Men's Combined    Gold                8.0
# ...

# %%
data19=data18.groupby('name')['Consecutive_Count'].count()

# %%
data19
# Out:
# name
# Kjetil Andr Aamodt         4
# Paavo Johannes Aaltonen    1
# Name: Consecutive_Count, dtype: int64
